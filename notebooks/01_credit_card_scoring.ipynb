# %%
# ============================================================
# Credit Card Scoring / Bank Marketing Prediction
# Proyecto: Predicción de aceptación de oferta financiera
# Dataset: Bank Marketing Dataset
# ============================================================

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    roc_auc_score,
    classification_report,
    confusion_matrix,
    ConfusionMatrixDisplay,
    RocCurveDisplay
)

# Crear carpeta outputs si no existe
os.makedirs("../outputs", exist_ok=True)

# ============================================================
# 1. Cargar dataset
# ============================================================

df = pd.read_csv("../data/bank.csv")

df.head()
# Out:
# The kernel failed to start as the Python Environment 'Python 3.11.1' is no longer available. Consider selecting another kernel or refreshing the list of Python Environments.
